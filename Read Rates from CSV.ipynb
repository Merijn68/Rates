# %%
import pandas as pd

# %% [markdown]
# Inlezen van de dataset - Conversie van kolommen naar string en date waar nodig

# %%
def ratesdata():
    date_cols = ["rate_dt","input_dt","actual_dt",'start_term_dt','maturity_term_dt']
    df = pd.read_csv(r'C:\Users\merij\OneDrive\Documents\Projects\temp.csv', parse_dates = date_cols, dtype ={"int_basis":'S10', "exchange_name": 'S10'})
    return df

# %%
df.head(5)
# Out:
#      rate_dt           rate_name  ccy   rate_type   seq_no curve_type  \
# 0 2020-10-01  CDS Asia Banking A  USD  End of Day  4621488      Yield
# 1 2020-10-01  CDS Asia Banking A  USD  End of Day  4621489      Yield
# 2 2020-10-01  CDS Asia Banking A  USD  End of Day  4621490      Yield
# 3 2020-10-01  CDS Asia Banking A  USD  End of Day  4621491      Yield
# 4 2020-10-01  CDS Asia Banking A  USD  End of Day  4621492      Yield
#
#     input_dt time_band  days_off  actual_dt  ...  start_term maturity_term  \
# 0 2020-10-01  6 MONTHS       2.0 2021-04-05  ...         NaN           NaN
# 1 2020-10-01    1 YEAR       2.0 2021-10-05  ...         NaN           NaN
# 2 2020-10-01   2 YEARS       2.0 2022-10-05  ...         NaN           NaN
# 3 2020-10-01   3 YEARS       2.0 2023-10-05  ...         NaN           NaN
# 4 2020-10-01   4 YEARS       2.0 2024-10-07  ...         NaN           NaN
#
#   start_term_dt  maturity_term_dt  start_term_date_days  \
# 0           NaT               NaT                   NaN
# 1           NaT               NaT                   NaN
# 2           NaT               NaT                   NaN
# 3           NaT               NaT                   NaN
# 4           NaT               NaT                   NaN
#
#   maturity_term_date_days exchange_name    bid  offer    mid
# 0                     NaN           b''  10.08  10.08  10.08
# 1                     NaN           b''  10.50  10.50  10.50
# 2                     NaN           b''  16.42  16.42  16.42
# 3                     NaN           b''  23.85  23.85  23.85
# 4                     NaN           b''  33.00  33.00  33.00
#
# [5 rows x 23 columns]

# %%
# get the columns for the result
cols = df.columns
print(cols)
# Out:
# Index(['rate_dt', 'rate_name', 'ccy', 'rate_type', 'seq_no', 'curve_type',
#        'input_dt', 'time_band', 'days_off', 'actual_dt', 'date_days',
#        'int_basis', 'int_days', 'start_term', 'maturity_term', 'start_term_dt',
#        'maturity_term_dt', 'start_term_date_days', 'maturity_term_date_days',
#        'exchange_name', 'bid', 'offer', 'mid'],
#       dtype='object')
